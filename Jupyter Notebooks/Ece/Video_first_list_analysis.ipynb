# %%
import pandas as pd

df =pd.read_excel('/Users/ececal/Downloads/video-list-first-draft.xlsx', index_col=0) 

df
# Out:
#              nrComments  nrThreads  nrReplies  maxThreadLength  disabled  \
# N7Qot_aax9M          32          5         13                8     False
# _evqapQpxUQ         108          5          8                2     False
# dcBXmj1nMTQ         120         13         20                7     False
# LxgMdjyw8uw         168         29         68              382     False
# 9PFhrpyWV-w         110          8         26                9     False
# ...                 ...        ...        ...              ...       ...
# hhI4IBC66sw          70         14         27                6     False
# 2CAG6Fg6Vlo         146         22         46                8     False
# afxhSL15KtQ         171         35         71               17     False
# uqwvf6R1_QY         141         19         41              493     False
# ULpGDnuz308         101          1          1                1     False
#
#              nrAuthors  nrAuthors3Posts  maxPostsByAuthor  \
# ...

# %%
ax = df['Content'].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrComments', ascending=False)

# %%
ax = df.iloc[0:50,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrComments', ascending=False)
ax = df.iloc[0:10,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrThreads', ascending=False)

# %%
ax = df.iloc[0:50,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrThreads', ascending=False)
ax = df.iloc[0:10,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrReplies', ascending=False)
ax = df.iloc[0:50,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrReplies', ascending=False)
ax = df.iloc[0:10,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('maxThreadLength', ascending=False)
ax = df.iloc[0:50,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('maxThreadLength', ascending=False)
ax = df.iloc[0:10,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrAuthors', ascending=False)
ax = df.iloc[0:50,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrAuthors', ascending=False)
ax = df.iloc[0:10,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrAuthors3Posts', ascending=False)
ax = df.iloc[0:50,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('nrAuthors3Posts', ascending=False)
ax = df.iloc[0:10,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('maxPostsByAuthor', ascending=False)
ax = df.iloc[0:50,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df= df.sort_values('maxPostsByAuthor', ascending=False)
ax = df.iloc[0:10,-1].value_counts(normalize=True).plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number for videos")
ax.set_xlabel("Content type")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
